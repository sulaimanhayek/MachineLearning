# %% [markdown]
# **These assignments are ungraded and are NOT to be submitted. Feedback is NOT available for these assignments, but you are welcome to discuss with a TA, or with me during one of the office hours, if you have any questions.**

# %% [markdown]
# # Optional Assignment 1 - Compare classification performance for multiple algorithms

# %% [markdown]
# Use the given UK Met (60km, 2010-2022) dataset to classify number of days of snow lying on the ground into 5 classes. Compare performance for kNN, SVM, logistic regression, and Bagging algorithms.

# %% [markdown]
# # Optional Assignment 2 - Implement own Bayes classifiers from scratch

# %% [markdown]
# For each test data instance in the 'Test data - mini' sheet of the 934G5 Excel version of the Iris dataset (https://canvas.sussex.ac.uk/courses/31315/files/folder/2025_lab%20materials?preview=5262599), find the probability of the three Iris species using your own implementation of a Bayes and/or Naive Bayes classifier. See Week 3 lecture for how the two classifiers work, i.e the maths to implement them.
# > The original Iris dataset publication is https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1469-1809.1936.tb02137.x.
#
# > *Fisher, R. A. (1936). The use of multiple measurements in taxonomic problems. Annals of eugenics, 7(2), 179-188.*
