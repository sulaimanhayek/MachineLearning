# %% [markdown]
# **You are welcome to email me (t.olugbade@sussex.ac.uk) your solution (pdf; max - 2 A4 pages, font size 12; deadline - Week 10), and I will provide general feedback for as many submissions as I can. You MUST include the completed ethics form (see Week 2 assignment notebook) as a separate attachment in your email to me.**

# %% [markdown]
# # Optional Assignment 1 - Predict sleepiness

# %% [markdown]
# Using Restfulness data that you started to collect in Week 2 (on yourself), build and evaluate a model for predicting next day sleepiness (or restfulness) using this dataset. To get started, think carefully about:
# * Which variable will you use for the machine learning labels?
# * How many classification (or regression) levels are appropriate for your labels?
# * Do you need to recode the variable?
# * What variables will you use for the machine learning features?
# * Do any of the features need to be recoded?
# * What learning algorithms would you try?
# * Do you need to restructure (or reshape) your data?
# * Are there any missing values that need to be addressed?
