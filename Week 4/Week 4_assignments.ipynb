# %% [markdown]
# **These assignments are ungraded and are NOT to be submitted. Feedback is NOT available for these assignments, but you are welcome to discuss with a TA, or with me during one of the office hours, if you have any questions.**

# %% [markdown]
# # Optional Assignment 1 - Build a MLP regression model

# %% [markdown]
# Train and evaluate a MLP model for automatic detection of the number of days of snow using the UK Met (60km, 2010-2022) data from Week 3. (Hint - This is a regression task). See if you can make the model reach mean absolute error of 1.0.
